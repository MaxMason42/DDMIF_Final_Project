# %%
import pandas as pd
import numpy as np
import empyrical
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns

# %%
df = pd.read_csv("results/tsmom/2023-2024/captured_returns_sw.csv")

# %%
df
# Out:
#        Unnamed: 0 identifier        time   returns  position  captured_returns
# 0               0        ADM  2023-01-03 -0.019575       1.0         -0.019575
# 1               1        ADM  2023-01-04 -0.012831       1.0         -0.012831
# 2               2        ADM  2023-01-05  0.010386       1.0          0.010386
# 3               3        ADM  2023-01-06 -0.003404       1.0         -0.003404
# 4               4        ADM  2023-01-09  0.005160       1.0          0.005160
# ...           ...        ...         ...       ...       ...               ...
# 10204       10204        WMT  2023-12-21  0.008528       1.0          0.008528
# 10205       10205        WMT  2023-12-22 -0.001096       1.0         -0.001096
# 10206       10206        WMT  2023-12-26  0.006832       1.0          0.006832
# 10207       10207        WMT  2023-12-27 -0.001438       1.0         -0.001438
# 10208       10208        WMT  2023-12-28  0.000378       1.0          0.000378
#
# ...

# %%
num_identifiers = None

if not num_identifiers:
    num_identifiers = len(df.dropna()["identifier"].unique())
srs = df.dropna().groupby('time')["captured_returns"].sum()/num_identifiers

# %%
srs
# Out:
# time
# 2023-01-03   -0.005943
# 2023-01-04   -0.001204
# 2023-01-05   -0.002852
# 2023-01-06   -0.000119
# 2023-01-09   -0.002175
#                 ...
# 2023-12-21    0.000329
# 2023-12-22    0.001432
# 2023-12-26    0.000699
# 2023-12-27   -0.001218
# 2023-12-28   -0.001197
# Name: captured_returns, Length: 249, dtype: float64

# %%
empyrical.calmar_ratio(srs)
# Out:
# 0.1427990271673798

# %%
len(srs[srs > 0.0]) / len(srs)
# Out:
# 0.4939759036144578

# %%
np.mean(srs[srs > 0.0])/ np.mean(np.abs(srs[srs < 0.0]))
# Out:
# 1.0526767595152742

# %%
momentum_file_paths = [
    "results/tsmom/2020-2021/captured_returns_sw.csv",
    "results/tsmom/2021-2022/captured_returns_sw.csv",
    "results/tsmom/2022-2023/captured_returns_sw.csv",
    "results/tsmom/2023-2024/captured_returns_sw.csv"
]

long_only_file_paths = [
    "results/long_only/2020-2021/captured_returns_sw.csv", 
    "results/long_only/2021-2022/captured_returns_sw.csv", 
    "results/long_only/2022-2023/captured_returns_sw.csv",
    "results/long_only/2023-2024/captured_returns_sw.csv"
]

lstm_file_paths = [
    "results/experiment_wrds_3year_train_lstm_cp21_len63_notime_div_v1/2020-2021/captured_returns_sw.csv",
    "results/experiment_wrds_3year_train_lstm_cp21_len63_notime_div_v1/2021-2022/captured_returns_sw.csv",
    "results/experiment_wrds_3year_train_lstm_cp21_len63_notime_div_v1/2022-2023/captured_returns_sw.csv",
    "results/experiment_wrds_3year_train_lstm_cp21_len63_notime_div_v1/2023-2024/captured_returns_sw.csv"
]

TFT_file_paths = [
    "results/experiment_wrds_3year_train_tft_cpnone_len252_notime_div_v1/2020-2021/captured_returns_sw.csv",
    "results/experiment_wrds_3year_train_tft_cpnone_len252_notime_div_v1/2021-2022/captured_returns_sw.csv",
    "results/experiment_wrds_3year_train_tft_cpnone_len252_notime_div_v1/2022-2023/captured_returns_sw.csv",
    "results/experiment_wrds_3year_train_tft_cpnone_len252_notime_div_v1/2023-2024/captured_returns_sw.csv"
]

TFT_CPD_file_paths = [
    "results/experiment_wrds_3year_train_tft_cp21_len252_notime_div_v1/2020-2021/captured_returns_sw.csv",
    "results/experiment_wrds_3year_train_tft_cp21_len252_notime_div_v1/2021-2022/captured_returns_sw.csv",
    "results/experiment_wrds_3year_train_tft_cp21_len252_notime_div_v1/2022-2023/captured_returns_sw.csv",
    "results/experiment_wrds_3year_train_tft_cp21_len252_notime_div_v1/2023-2024/captured_returns_sw.csv"
]

TFT_extended_file_paths = [
    "results/experiment_wrds_3year_train_tft_cpnone_len378_notime_div_v1/2020-2021/captured_returns_sw.csv",
    "results/experiment_wrds_3year_train_tft_cpnone_len378_notime_div_v1/2021-2022/captured_returns_sw.csv",
    "results/experiment_wrds_3year_train_tft_cpnone_len378_notime_div_v1/2022-2023/captured_returns_sw.csv",
    "results/experiment_wrds_3year_train_tft_cpnone_len378_notime_div_v1/2023-2024/captured_returns_sw.csv"
]

TFT_CPD_extended_file_paths = [
    "results/experiment_wrds_3year_train_tft_cp21_len378_notime_div_v1/2020-2021/captured_returns_sw.csv",
    "results/experiment_wrds_3year_train_tft_cp21_len378_notime_div_v1/2021-2022/captured_returns_sw.csv",
    "results/experiment_wrds_3year_train_tft_cp21_len378_notime_div_v1/2022-2023/captured_returns_sw.csv",
    "results/experiment_wrds_3year_train_tft_cp21_len378_notime_div_v1/2023-2024/captured_returns_sw.csv"
]

TFT_heads_file_paths = [
    "results/experiment_wrds_3year_train_6heads_tft_cpnone_len252_notime_div_v1/2020-2021/captured_returns_sw.csv",
    "results/experiment_wrds_3year_train_6heads_tft_cpnone_len252_notime_div_v1/2021-2022/captured_returns_sw.csv",
    "results/experiment_wrds_3year_train_6heads_tft_cpnone_len252_notime_div_v1/2022-2023/captured_returns_sw.csv",
    "results/experiment_wrds_3year_train_6heads_tft_cpnone_len252_notime_div_v1/2023-2024/captured_returns_sw.csv"
]

TFT_CPD_heads_file_paths = [
    "results/experiment_wrds_3year_train_6heads_tft_cp21_len252_notime_div_v1/2020-2021/captured_returns_sw.csv",
    "results/experiment_wrds_3year_train_6heads_tft_cp21_len252_notime_div_v1/2021-2022/captured_returns_sw.csv",
    "results/experiment_wrds_3year_train_6heads_tft_cp21_len252_notime_div_v1/2022-2023/captured_returns_sw.csv",
    "results/experiment_wrds_3year_train_6heads_tft_cp21_len252_notime_div_v1/2023-2024/captured_returns_sw.csv"
]

# %%
def read_and_get_returns(file_paths):
    dfs = [pd.read_csv(file) for file in file_paths]
    df = pd.concat(dfs, ignore_index=True)

    df['time'] = pd.to_datetime(df['time'])

    num_identifiers = None

    if not num_identifiers:
        num_identifiers = len(df.dropna()["identifier"].unique())
    
    avg_returns = df.dropna().groupby('time')["captured_returns"].sum()/num_identifiers

    return (1 + avg_returns).cumprod() - 1

# %%
momentum = read_and_get_returns(momentum_file_paths)
long = read_and_get_returns(long_only_file_paths)
lstm_returns = read_and_get_returns(lstm_file_paths)
TFT_returns = read_and_get_returns(TFT_file_paths)
TFT_CPD_returns = read_and_get_returns(TFT_CPD_file_paths)
TFT_extended = read_and_get_returns(TFT_extended_file_paths)
TFT_CPD_extended = read_and_get_returns(TFT_CPD_extended_file_paths)
TFT_heads = read_and_get_returns(TFT_heads_file_paths)
TFT_CPD_heads = read_and_get_returns(TFT_CPD_heads_file_paths)

# %%
plt.figure(figsize=(12, 6))

plt.plot(long.index, long, label="Long-Only")
plt.plot(momentum.index, momentum, label="Momentum")
plt.plot(lstm_returns.index, lstm_returns, label="LSTM")
plt.plot(TFT_returns.index, TFT_returns, label="TFT")
plt.plot(TFT_CPD_returns.index, TFT_CPD_returns, label="TFT-CPD")
plt.plot(TFT_CPD_heads.index, TFT_CPD_heads, label = "TFT-CPD-6")

plt.xlabel('Date')
plt.ylabel("Cummulative Return")
plt.title("Strategy Returns")

plt.gca().xaxis.set_major_locator(mdates.YearLocator()) 
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

plt.legend()
plt.show()

# %%
df = pd.read_csv("data\wrds_cpd_nonelbw.csv")
df = df[df["Date"] >= "2022-01-01"]
df = df[df["Date"] <= "2022-12-31"]
df_pivot = df.pivot(index="Date", columns="ticker", values="daily_returns")

covariance_matrix = df_pivot.cov() * 252

# %%
covariance_matrix.iloc[:20, :20]
# Out:
# ticker       ADM       ALB      ALCO      AMZN        BA       BAC        BG  \
# ticker
# ADM     0.096631  0.061200  0.041272  0.044454  0.036267  0.037994  0.083015
# ALB     0.061200  0.302078  0.055146  0.124924  0.122389  0.087067  0.052938
# ALCO    0.041272  0.055146  0.133390  0.042713  0.036114  0.036493  0.043718
# AMZN    0.044454  0.124924  0.042713  0.250774  0.116776  0.089390  0.043556
# BA      0.036267  0.122389  0.036114  0.116776  0.218820  0.082603  0.035274
# BAC     0.037994  0.087067  0.036493  0.089390  0.082603  0.105886  0.042431
# BG      0.083015  0.052938  0.043718  0.043556  0.035274  0.042431  0.111055
# BKNG    0.036190  0.129362  0.031650  0.117774  0.114042  0.079984  0.032246
# C       0.036532  0.084484  0.035273  0.084893  0.083972  0.089370  0.043501
# CAH     0.033991  0.047628  0.022357  0.035831  0.044367  0.037975  0.030280
# CMCSA   0.026780  0.055483  0.023394  0.066949  0.051668  0.045625  0.027140
# ...

# %%
plt.figure(figsize=(14, 8)) 
sns.heatmap(covariance_matrix.iloc[:15, :15], annot=True, cmap='coolwarm') 
plt.title('Covariance Matrix Heatmap')
plt.show()
